# %% [markdown]
# ## nuage de points with sklearn

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Fix random seed for reproducibility
np.random.seed(44)

# Define the coefficients of the true line
a = 2
b = 3

# Data generation
number_of_points = 100
X = np.random.rand(number_of_points) * 10 
noise = np.random.randn(number_of_points) * 2  # Gaussian noise with standard deviation 2
y = a * X + b + noise 

# Display the scatter plot
plt.scatter(X, y, label='Data')

# Reshape X to fit the model
X = np.reshape(X, (len(X), 1))

# Create the linear regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Predict values with the trained model
y_pred = model.predict(X)

plt.plot(X, y_pred, color='red', label='Linear Regression')

plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression on a Scatter Plot")
plt.legend()

plt.show()

# Display the coefficients learned by the model
print("Slope (coefficient a):", model.coef_[0])
print("Intercept (bias):", model.intercept_)

# Calculate errors
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Display errors
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R² Score:", r2)
# Out:
# Slope (coefficient a): 2.0116096707021507
# Intercept (bias): 2.7109520613362648
# Mean Absolute Error (MAE): 1.6682256522421404
# Mean Squared Error (MSE): 4.421952709910318
# R² Score: 0.8897898921124716
